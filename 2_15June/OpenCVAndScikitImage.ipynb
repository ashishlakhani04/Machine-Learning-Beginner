# %% [markdown]
# # OpenCV And ScikitImage

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import cv2
import skimage.io as io

# %%
#Loading an Image
img = cv2.imread('img1.png')
im = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
print(img.shape,type(img),img.dtype)
# Out:
# (1800, 2880, 3) <class 'numpy.ndarray'> uint8

# %%
# Display an image
plt.figure(0)
# plt.imshow(im)
# plt.imshow(im,cmap='gray')
plt.subplot(1, 2, 1)
plt.imshow(im[:, :, 0], cmap='gray')
plt.show()
